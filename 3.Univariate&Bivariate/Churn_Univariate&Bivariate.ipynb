# %% [markdown]
# ## <span style="color:blue; font-size:22px;">3.1 Univariate Analysis</span>

# %%
df_clean.describe()
# Out:
#         CreditScore        Gender           Age        Tenure        Balance  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean     650.528800      0.545700     38.921800      5.012800   76485.889288
# std       96.653299      0.497932     10.487806      2.892174   62397.405202
# min      350.000000      0.000000     18.000000      0.000000       0.000000
# 25%      584.000000      0.000000     32.000000      3.000000       0.000000
# 50%      652.000000      1.000000     37.000000      5.000000   97198.540000
# 75%      718.000000      1.000000     44.000000      7.000000  127644.240000
# max      850.000000      1.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# ...

# %%
print(df_clean['Exited'].value_counts())
print(df['Geography'].value_counts())
print(df_clean['Gender'].value_counts())
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64
# Gender
# 1    5457
# 0    4543
# Name: count, dtype: int64

# %%
# Target Variable Distribution

# %%
sns.countplot(x='Exited', data=df_clean)
plt.title("Customer Churn Distribution", fontsize=13, fontweight='bold')
plt.show()

print(df_clean['Exited'].value_counts(normalize=True) * 100)
# Out:
# Exited
# 0    79.63
# 1    20.37
# Name: proportion, dtype: float64

# %%
# Age Distribution

# %%
sns.histplot(df_clean['Age'], kde=True, bins=30)
plt.title("Age Distribution of Customers")
plt.show()

# %%
# Credit score Distribution

# %%
sns.histplot(df_clean['CreditScore'], kde=True, bins=30)
plt.title("Credit Score Distribution")
plt.xlabel("Credit Score")
plt.ylabel("Customers")
plt.show()

# %%
# Customer Balance Distribution

# %%
sns.histplot(df_clean['Balance'], kde=True, bins=30)
plt.title("Customer Balance Distribution")
plt.show()

# %%
# Estimated Salary Distribution

# %%
sns.histplot(df_clean['EstimatedSalary'], kde=True, bins=30)
plt.title("Estimated Salary Distribution")
plt.show()

# %%
# Products Distribution

# %%
sns.countplot(x='NumOfProducts', data=df_clean)
plt.title("Number of Products Distribution")
plt.show()

# %%
# Distribution by Geography

# %%
sns.countplot(x='Geography', data=df)
plt.title("Customer Distribution by Geography")
plt.show()

# %%
# Gender Distribution

# %%
sns.countplot(x='Gender', data=df)
plt.title("Gender Distribution")
plt.show()

# %%
# Active vs Inactive Customer Distribution

# %%
sns.countplot(x='IsActiveMember', data=df_clean)
plt.title("Active vs Inactive Customers")
plt.show()

# %% [markdown]
# ## <span style="color:blue; font-size:22px;">3.2 Bivariate Analysis</span>

# %%
df_clean.groupby('Exited')['Age'].mean()
# Out:
# Exited
# 0    37.408389
# 1    44.837997
# Name: Age, dtype: float64

# %%
pd.crosstab(df['Geography'], df['Exited'])
pd.crosstab(df['Gender'], df['Exited'])
# Out:
# Exited     0     1
# Gender
# Female  3404  1139
# Male    4559   898

# %%
# Age vs Customer Churn

# %%
sns.boxplot(x='Exited', y='Age', data=df_clean)
plt.title("Age vs Customer Churn")
plt.show()

# %%
sns.countplot(x='Geography', hue='Exited', data=df)
plt.title("Geography vs Customer Churn")
plt.show()

# %%
sns.countplot(x='Gender', hue='Exited', data=df)
plt.title("Gender vs Customer Churn")
plt.show()

# %%
sns.boxplot(x='Exited', y='Balance', data=df_clean)
plt.title("Balance vs Customer Churn")
plt.show()

# %%
sns.boxplot(x='Exited', y='CreditScore', data=df_clean)
plt.title("Credit Score vs Customer Churn")
plt.show()

# %%
sns.boxplot(x='Exited', y='Tenure', data=df_clean)
plt.title("Tenure vs Customer Churn")
plt.show()

# %%
sns.countplot(x='NumOfProducts', hue='Exited', data=df_clean)
plt.title("Number of Products vs Churn")
plt.show()

# %%
sns.countplot(x='IsActiveMember', hue='Exited', data=df_clean)
plt.title("Active Member vs Churn")
plt.show()

# %%
sns.boxplot(x='Exited', y='EstimatedSalary', data=df_clean)
plt.title("Salary vs Customer Churn")
plt.show()

# %%
sns.countplot(x='HasCrCard', hue='Exited', data=df_clean)
plt.title("Credit Card vs Customer Churn")
plt.show()
